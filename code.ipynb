# %%
import numpy as np 
import trimesh
import potpourri3d as pp3d
import torch
import scipy

import matplotlib.pyplot as plt 
from matplotlib import colors, cm

# %%
mesh = trimesh.load("mesh.obj",maintain_order=True, process=False)

# %%
#calculate L, M
def compute_operators(verts_np, faces_np, eps = 1e-8):
    L = pp3d.cotan_laplacian(verts_np, faces_np, denom_eps=1e-10)

    massvec_np = pp3d.vertex_areas(verts_np, faces_np)
    massvec_np += eps * np.mean(massvec_np)

    return L, massvec_np

# %%
verts = mesh.vertices
faces = mesh.faces

L,M = compute_operators(verts, faces)

# %%
#diffusion
def diffusion(L, M, u, t=0.01):
    
    L = torch.Tensor(L.todense())
    M = torch.Tensor(M)
    u = torch.Tensor(u)
    mat_dense = L.unsqueeze(0) * t
    mat_dense += torch.diag_embed(M).unsqueeze(0) 
    # Factor the system
    cholesky_factors = torch.linalg.cholesky(mat_dense)

    # Solve the system
    rhs = u * M.unsqueeze(-1) 
    rhsT = torch.transpose(rhs, 0,1)
    sols = torch.cholesky_solve(rhsT.unsqueeze(0), cholesky_factors) 
    

    return sols.squeeze(0)

# %%
u = np.zeros(verts.shape[0])
u[0] = 1
u_diffuse =diffusion(L,M,u,t=10)

# %%
def getColorMap(v):
    """ Maps each value of a given vector to a colour. Min value gets mapped to blue and 
    max value gets mapped to red
    Input: v: A vector
    """
    
    jet = plt.get_cmap('jet')
    cNorm  = colors.Normalize(v.min(), v.max())
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=jet)
    point_colours = np.zeros((mesh.vertices.shape[0], 3))

    for i in range(v.shape[0]):
        point_colours[i] = scalarMap.to_rgba(v[i])[:3]
    return point_colours

# %%
colors_init = getColorMap(u)
colors_new = getColorMap(u_diffuse[:,0])

m1 = trimesh.Trimesh(verts,faces,vertex_colors=colors_init)
m1.export('pre.ply')

m2 = trimesh.Trimesh(verts,faces,vertex_colors=colors_new)
m2.export('diffused10.ply')
# Out:
# b'ply\nformat binary_little_endian 1.0\ncomment https://github.com/mikedh/trimesh\nelement vertex 6890\nproperty float x\nproperty float y\nproperty float z\nproperty uchar red\nproperty uchar green\nproperty uchar blue\nproperty uchar alpha\nelement face 13776\nproperty list uchar int vertex_indices\nend_header\n_%\x9f\xbd\xe7\xdf2?\x86s\xcd=\x80\x00\x00\xff\xa3?\xb4\xbdU\xf8/?\xc3\x9f\xc1=\xff8\x00\xffx\xd2\xa2\xbd\x18x.? (\xd7=\xffG\x00\xff\xe8\xa3\x8c\xbd\x80\x810?<\xdb\xe3=\xff;\x00\xffD\x14\xb3\xbd\xd5\xaf,?b\x84\xd0=\xffh\x00\xff\x88\xd8\xc0\xbd5~-?T\xe5\xbb=\xffh\x00\xffSB\x90\xbd\xee`,?Z\xf6\xe4=\xffs\x00\xff\xd9\xear\xbd\xf9h-?\x1d\xca\xf0=\xffz\x00\xff\xb1l\x86\xbd\xbe\x9f"?g\xb9\xec=\xff\xc8\x00\xff\xde;j\xbdP\xfc ?\xd5\xaf\xf4=\xff\xd7\x00\xff\x8cfe\xbd\x1d;$?\x197\xf5=\xff\xc4\x00\xff\xcbh\x84\xbdL\x18%?-[\xeb=\xff\xb6\x00\xff\xafB\x8a\xbd)\x96\x1b?Y\xfc\xe6=\xfe\xed\x00\xffL\xc7\x9c\xbd\x99\xbc\x19?\xfb]\xd8=\xf8\xf5\x00\xff\xb8w\x8d\xbd\xc0\xcd\x16?\x88*\xdc=\xeb\xff\x0c\xff\xe8\xc0r\xbd\xa6\xd1\x18?\x9c\x89\xe9=\xf1\xfc\x06\xff\xc9q\xc7\xbd\xb9\xc3\x1e?\xa1K\x98=\xff\xde\x00\xff\\=\xc7\xbd\xe8\xd9\x1c? )\xa2=\xff\xea\x00\xff\xfbX\xc1\xbdV\x9c\x1e?e\xde\xaa=\xff\xde\x00\xff\x08\x90\xc1\xbd\xd3K ?\xe4\xbc\x9f=\xff\xd7\x00\xffF\xb6\xd3\xbd\x97\x02"?m\x8d\x88=\xff\xd7\x00\xff0*\xc9\xbd\\9#?\x15\xc5\x8b=\xff\xd0\x00\xff\xde\x03\xd4\xbd\x92\x94$?\x06*\x83=\xff\xd0\x00\xff\rm\xe0\xbd\xc9 #?\xf47\x81=\xff\xd7\x00\xff\x98\xf6\xcd\xbd\xeaw\x1d?MN\x8d=\xff\xe6\x00\xff\x9fu\xcd\xbdS^\x1b?\xe7q\x98=\xfb\xf1\x00\xff\xc2\xf8\xc9\xbdF\x96 ?<\x15\x90=\xff\xdb\x00\xffYi\xd2\xbdZ\x83\x1f?-[\x8b=\xff\xde\x00\xff\xf8Q\xed\xbd\xc2h\x1e?\xdbL\x85=\xff\xea\x00\xffa\x89\xe7\xbd6\x93\x1f?\x16P\x88=\xff\xe2\x00\xff\xd8\xf3\xf5\xbd\x8b5 ?\xa8\x01\x83=\xff\xe6\x00\xff\xe2"\xf7\xbd\x91\xd0\x1e?\x01i\x7f=\xff\xea\x00\xff\x8f7\xd9\xbd\x8a\xac\x1d?\x11\xe2\x8a=\xff\xea\x00\xff2\x92\xdd\xbd\xb1\xa2\x1e?#/\x8b=\xff\xe6\x00\xff\n\x10\xe5\xbd\xbf\xb7\x1d?\xab\xed\x86=\xff\xea\x00\xff\xc4\x99\xdf\xbd\x98\xf7\x1c?N^\x84=\xfe\xed\x00\xff?\x90\xdc\xbd\x9a\xef ?#\x15\x86=\xff\xde\x00\xff\xb1\x1a\xeb\xbd\xe5\xd5!?\xc4\x08\x81=\xff\xde\x00\xff9\xd2\xf9\xbd\xc3\x83"?4\x9cr=\xff\xe2\x00\xff\x1b\x7f\x02\xbe\xa1\x85 ?\x03\nu=\xff\xe6\x00\xff\xe9\x9c\xbf\xbd\xa1\xd6\x18?\x1f\xb9\xb5=\xf4\xf8\x02\xff\x00\x1a\xc5\xbd\x1d\xe3\x1a?\xc8\xec\xac=\xfb\xf1\x00\xffS\x97\xcc\xbdK\x90\x19?f\xbe\xa3=\xf4\xf8\x02\xffb.\xc9\xbd\x84\xd6\x17?\x8c\xf2\xac=\xee\xff\t\xff\xf3u\xd9\xbd\x1e\xde\x1b?\x03^\x86=\xfb\xf1\x00\xffK<\xe0\xbd\xbc]\x17?\xc3\xa0\x8c=\xeb\xff\x0c\xff\x8eW\xe0\xbdlz\x18?\xfc\xfe\x8d=\xee\xff\t\xffs\xd6\xe7\xbd\xc3\xf1\x18?\xc6\xe0\x81=\xee\xff\t\xff\xdb\x88\xe7\xbd\xcd\xe4\x17?.\xff\x81=\xeb\xff\x0c\xff"\x88\xb3\xbd/3\x14?~p\xbe=\xe1\xff\x16\xff\x07\xb5\xbf\xbd&\x1a\x14?vQ\xb4=\xe1\xff\x16\xff\x03\x93\xbb\xbd\x1e\xe0\x11? \xb3\xb3=\xdb\xff\x1c\xffu\x01\xaf\xbd\x81\x93\x11?\xceS\xbd=\xd7\xff\x1f\xff\x9c\xe0\xbb\xbd\x0c\x01\x10?\'\x84\xae=\xd4\xff#\xff\xa8\x90\xab\xbd\xed\xd2\x0e?$D\xb9=\xd1\xff&\xff\x04\xa9\xb4\xbd\x10@\n?\x90\xbb\xa8=\xc4\xff3\xff\xf7!\xaf\xbd\x8dc\x0c?\x8b\xfe\xb0=\xc7\xff0\xff\x00\x03\xc1\xbd\xd1>\x0e?l\xb5\xa7=\xce\xff)\xff\xab\x04\xcb\xbdT\xc9\x0c?\x93\xc5\x9d=\xca\xff,\xff(\xf4\xda\xbdu\x01\x0f?\xb6\x82\x86=\xd1\xff&\xff\t\xf9\xe0\xbdr\xfe\x0e?C\xe4t=\xd1\xff&\xff\xcd\x95\xe1\xbdJ&\x0b?\xa2\xb5\x82=\xc7\xff0\xff$\x0b\xd8\xbd\x1e\xa8\x0b?+j\x90=\xc7\xff0\xff\xfb\x96\xd9\xbd\x9cn\x15?\xb1\x86\x8b=\xe4\xff\x13\xffY\xa2\xd3\xbdVD\x15?D\x14\x93=\xe4\xff\x13\xffA\x81\xd7\xbdN\xd5\x15?\xc7\xa0\x93=\xe7\xff\x0f\xffv\x19\xde\xbd&V\x16?v\xc2\x8b=\xe7\xff\x0f\xff\xef\x00\xcf\xbd\xbb\x0e\x15?n\x17\x9a=\xe4\xff\x13\xffJC\xcd\xbd\xe0\xf2\x14?O>\x9d=\xe4\xff\x13\xff>\xb4\xcf\xbd=e\x15?\x04\x02\x9d=\xe4\xff\x13\xffW"\xd0\xbd8K\x15?\xa7\x06\x9a=\xe4\xff\x13\xff\x06\xa0\xd1\xbd78\x15?|B\x96=\xe4\xff\x13\xff\x04p\xd3\xbd2\xae\x14?\xa3?\x94=\xe1\xff\x16\xff\xbek\xd0\xbdj\xdb\x14?\xee\\\x98=\xe4\xff\x13\xff\xe4\x9f\xd9\xbd1x\x14?\xb0\x8c\x8d=\xe1\xff\x16\x ...
